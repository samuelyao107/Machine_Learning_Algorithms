# %%
# The load_diabetes dataset contains information about diabetes patients, including various health measurements.
# It consists of 442 samples with 10 feature variables, which are:
# - age: Age of the patient
# - sex: Sex of the patient (1 = male; 0 = female)
# - bmi: Body mass index (weight in kg / (height in m)^2)
# - bp: Average blood pressure (mm Hg)
# - s1: TC (total cholesterol) 
# - s2: LDL (low-density lipoprotein)
# - s3: HDL (high-density lipoprotein)
# - s4: LDL/HDL ratio
# - s5: glucose level (mg/dL)
# - s6: insulin level (µU/mL)
#
# The target variable is a continuous measure of diabetes progression one year after baseline, 
# making it suitable for regression tasks to predict how the disease will progress.



from sklearn.datasets import load_diabetes
data = load_diabetes()

# %%
import numpy as np

from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(data.data, data.target)
X_scaler = StandardScaler()
y_scaler = StandardScaler()
X_train = X_scaler.fit_transform(X_train)
y_train = y_scaler.fit_transform(y_train.reshape(-1, 1))
X_test = X_scaler.transform(X_test)
y_test = y_scaler.transform(y_test.reshape(-1, 1))
regressor = SGDRegressor(loss='squared_error')
scores = cross_val_score(regressor, X_train, y_train, cv=5)
print('Cross validation r-squared scores: %s' % scores)
print('Average cross validation r-squared score: %s' % np.mean(scores))
regressor.fit(X_train, y_train)
print('Test set r-squared score %s' % regressor.score(X_test, y_test))
# Out:
# Cross validation r-squared scores: [0.48919568 0.50821182 0.50533017 0.59975078 0.40887969]
# Average cross validation r-squared score: 0.5022736302533772
# Test set r-squared score 0.41800736793311033
# C:\Users\mercz\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   X : {ndarray, list, sparse matrix}
# C:\Users\mercz\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   X : {ndarray, list, sparse matrix}
# C:\Users\mercz\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...

# %%
import pandas as pd

df = pd.read_csv('Data/winequality-red.csv', sep=';')
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
import matplotlib.pylab as plt

plt.scatter(df['alcohol'], df['quality'])
plt.xlabel('Alcohol')
plt.ylabel('Quality')
plt.title('Alcohol Against Quality')
plt.show()

# %%
plt.scatter(df['density'], df['quality'])
plt.xlabel('density')
plt.ylabel('Quality')
plt.title('density Against Quality')
plt.show()

# %%
plt.scatter(df['fixed acidity'], df['quality'])
plt.xlabel('fixed acidity')
plt.ylabel('Quality')
plt.title('fixed acidity Against Quality')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pylab as plt
from sklearn.model_selection import train_test_split

df = pd.read_csv('Data/winequality-red.csv', sep=';')
X = df[list(df.columns)[:-1]]
y = df['quality']
X_train, X_test, y_train, y_test = train_test_split(X, y)
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_predictions = regressor.predict(X_test)
print('R-squared: %s' % regressor.score(X_test, y_test))
# Out:
# R-squared: 0.40020728000904415
